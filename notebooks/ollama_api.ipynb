# %%
from ollama import chat
from ollama import ChatResponse

# %%
response: ChatResponse = chat(model='llama3', messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
print(response['message']['content'])
# or access fields directly from the response object
print(response.message.content)
# Out:
# The sky appears blue to our eyes because of a phenomenon called Rayleigh scattering, named after the British physicist Lord Rayleigh. Here's what happens:
#
# When sunlight enters Earth's atmosphere, it encounters tiny molecules of gases such as nitrogen (N2) and oxygen (O2). These molecules are much smaller than the wavelength of light itself.
#
# As the light interacts with these molecules, it scatters in all directions. The amount of scattering that occurs depends on the wavelength of the light and the size of the molecules.
#
# The shorter wavelengths of light, such as blue and violet, are scattered more than the longer wavelengths, like red and orange. This is because the smaller molecules are better at scattering the shorter wavelengths.
#
# As a result of this selective scattering, our eyes perceive the sky as blue during the daytime when the sun is overhead. The blue light that is scattered in all directions reaches our eyes from all parts of the sky, making it appear blue.
#
# Here's why the sky can take on other colors during different times:
#
# * During sunrise and sunset, the sun appears more red because the shorter wavelengths (like blue) are scattered away by atmospheric particles, leaving mainly longer wavelengths (like red) to reach our eyes.
# * At higher altitudes or in areas with less atmosphere, the sky can appear whiter or more gray, as there is less scattering of light.
# * During dust storms or heavy pollution, the air can scatter light in different ways, making the sky appear hazy or orange.
#
# So, to summarize: the sky appears blue because of the selective scattering of sunlight by tiny atmospheric molecules, which favors shorter wavelengths like blue and violet.
# The sky appears blue to our eyes because of a phenomenon called Rayleigh scattering, named after the British physicist Lord Rayleigh. Here's what happens:
#
# When sunlight enters Earth's atmosphere, it encounters tiny molecules of gases such as nitrogen (N2) and oxygen (O2). These molecules are much smaller than the wavelength of light itself.
#
# As the light interacts with these molecules, it scatters in all directions. The amount of scattering that occurs depends on the wavelength of the light and the size of the molecules.
#
# The shorter wavelengths of light, such as blue and violet, are scattered more than the longer wavelengths, like red and orange. This is because the smaller molecules are better at scattering the shorter wavelengths.
#
# As a result of this selective scattering, our eyes perceive the sky as blue during the daytime when the sun is overhead. The blue light that is scattered in all directions reaches our eyes from all parts of the sky, making it appear blue.
#
# Here's why the sky can take on other colors during different times:
#
# * During sunrise and sunset, the sun appears more red because the shorter wavelengths (like blue) are scattered away by atmospheric particles, leaving mainly longer wavelengths (like red) to reach our eyes.
# * At higher altitudes or in areas with less atmosphere, the sky can appear whiter or more gray, as there is less scattering of light.
# * During dust storms or heavy pollution, the air can scatter light in different ways, making the sky appear hazy or orange.
#
# So, to summarize: the sky appears blue because of the selective scattering of sunlight by tiny atmospheric molecules, which favors shorter wavelengths like blue and violet.

# %%
stream = chat(
    model='llama2-uncensored',
    messages=[{'role': 'user', 'content': 'Why eating biblically is good for you health? Give me a list of ingredients and foods that I can eat!'}],
    stream=True,
)

for chunk in stream:
  print(chunk['message']['content'], end='', flush=True)
# Out:
# Eating biblically, or according to the teachings of Jesus Christ, has numerous benefits for your health. Some of these include improved digestion, better nutrient absorption, increased energy levels, and a reduced risk of chronic diseases such as heart disease, diabetes, and cancer. To get started with biblically healthy eating, consider incorporating the following ingredients and foods into your diet:
# 1. Fruits and vegetables: These are packed with essential vitamins, minerals, antioxidants, and fiber that are beneficial for overall health. Some recommended fruits include apples, blueberries, cherries, oranges, and strawberries, while vegetables such as broccoli, spinach, carrots, tomatoes, and avocado should also be included in your diet.
# 2. Lean protein sources: These are excellent sources of essential amino acids that help build and repair muscle tissue. Some recommended lean proteins include fish, chicken, turkey, legumes (such as lentils or beans), tofu, and eggs.
# 3. Whole grains: These are high in fiber, which helps regulate digestion and maintain healthy gut bacteria. Some examples of whole grains include quinoa, oats, brown rice, millet, and buckwheat.
# 4. Healthy fats: These include unsaturated fats such as omega-3 fatty acids found in fish or nuts, and monounsaturated fats from sources like avocados, olive oil, and nut butters.
# 5. Spices and herbs: These can add flavor to your meals without adding excess sodium or unhealthy ingredients. Some recommended spices include cinnamon, turmeric, ginger, garlic, and black pepper.
# By incorporating these ingredients and foods into your diet, you can enjoy a healthier, more balanced meal plan that meets the guidelines of biblically healthy eating.
